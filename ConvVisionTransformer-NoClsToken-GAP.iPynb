# %%
from torch import optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np 
import random
import torchvision 
import torch.nn.functional as functional

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
# !nvidia-smi
# Out:
# Fri Dec 12 16:25:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.80                 Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 34%   30C    P8            N/A  /  115W |    1414MiB /   8188MiB |      8%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            8272    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            8864    C+G   ....1.3.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A            9184    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10016    C+G   C:\Windows\System32\dwm.exe           N/A      |
# |    0   N/A  N/A           10800    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           11568    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           11624    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           16568    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16796    C+G   ...yApp\MicrosoftSecurityApp.exe      N/A      |
# |    0   N/A  N/A           17056    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           19416    C+G   ...abra\Direct6\jabra-direct.exe      N/A      |
# |    0   N/A  N/A           21428    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           21636    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           24652    C+G   ...ams\Perplexity\Perplexity.exe      N/A      |
# |    0   N/A  N/A           24784    C+G   ...__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A           25076    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           25336    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           25620    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           26212    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           28624    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           30304    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           30452    C+G   ...r\Mystic Light\LEDKeeper2.exe      N/A      |
# |    0   N/A  N/A           30596    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           31080    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           31920    C+G   ...64__8wekyb3d8bbwe\Copilot.exe      N/A      |
# |    0   N/A  N/A           32232    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           33108    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           33448    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           33696    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           35408    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           36504    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Setting uniform seed

# %%
torch.manual_seed(32)
torch.cuda.manual_seed(32)
random.seed(42)

# %%
# Set Hyper Parameters

# %%
BATCH_SIZE = 128
EPOCHS = 10
LEARNING_RATE = 3e-4
LION_LEARNING_RATE= 1e-4
PATCH_SIZE = 4
NUM_CLASSES=10 # for CIFAR
IMAGE_SIZE = 32
CHANNELS = 3
EMBEDDING_DIM = 384
NUM_HEADS = 8
DEPTH = 12 # Number of Transformer Encoder Blocks
MLP_DIM = 512
DROPOUT_RATE=0.1

# %%
#Patch Embedding , Create patches and return Tensor of Dimansion :  128 X 65 X 384 : 128 images 65 tokens(patches + CLS) per image, 
#384d per token (384d vector per patch)

class PatchEmbedding(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, embedding_dim):
        super().__init__()
        self.patch_size = patch_size
       # IMPORTANT : Use Convolution 2d as Projection Layer as its more efficient than a Linear Layer . The paper actually Mentions a Linear Layer . 
       # kernel and stride are assigned to patch size as we want patches and not overlaps  
        self.projection = nn.Conv2d(in_channels = in_channels, out_channels = embedding_dim, kernel_size = patch_size , stride=patch_size)
       # For square images number of patches is (image size/patch size) ^2         
        num_patches = (image_size//patch_size)**2
        #The CLS token (classification token) in Vision Transformers is a special learnable parameter that serves as a placeholder
        #for aggregating global information from all image patches for classification tasks
        self.pos_embed = nn.Parameter(torch.randn(1, num_patches + 1, embedding_dim))
      #  self.cls_token = nn.Parameter(torch.randn(1, 1, embedding_dim)) # Random to begin with

                                      
    def forward(self, tensor: torch.Tensor):
            # Tensor is 128 X 3 X 32 X 32 ( 3 , 32, 32 is the image 32X32 with 3 channels) 
            batch_size = tensor.size(0) # Get Batch Size 
            projected_tensor = self.projection(tensor)  # Each patch becomes 384d feature vector Tensor is now : 128*384*8*8
            flattened_tensor = projected_tensor.flatten(2) # flatten 128*384*8*8 to 128, 384, 64
            transposed_tensor = flattened_tensor.transpose(1,2) # swap to : 128 *64*384 converts tensor to format (batch_size, sequence_length, embedding_dim) by swapping dims: 
          #  cls_token = self.cls_token.expand(batch_size, -1, -1) # cls_token is replicated to all 128 images in the batch 
          #  tensor_with_cls_token = torch.cat((cls_token, transposed_tensor), dim=1)   # CLS Token in position 0 , Position 1 to 64 image patches
           # print(transposed_tensor.shape)
            #tensor_with_Pos_Embed = transposed_tensor + self.pos_embed 
         #   print(tensor_with_Pos_Embed.shape)
            return transposed_tensor # 128 X 65 X 384 : 128 images 65 tokens per image ( CLS token + 64 Patches), 384D representation of each token

# %%
class MLP(nn.Module):
    def __init__(self, in_features, hidden_features, dropout_rate):
        super().__init__()
        self.fc1 = nn.Linear(in_features=in_features, out_features=hidden_features)
        self.fc2 = nn.Linear(in_features=hidden_features, out_features=in_features)
        self.dropout = nn.Dropout(dropout_rate)
    def forward(self, tensor): # EXPAND ACTIVATE PROJECT BACK , Maintains original Dimensions 
        tensor = self.fc1(tensor)  # Tensor is  128 X 65 X 384 , output is 128 X 65 X 512
        tensor = self.dropout(functional.gelu(tensor)) # Input & output is 128 X 65 X 512 , Activation Function : Gaussian Error Linear Unit
        tensor = self.dropout(self.fc2(tensor)) # input is 128 X 65 X 512 and output is 128 X 65 X 384
        return tensor

# %%
class ConvTransformerEncoder(nn.Module): 
    def __init__(self, embedding_dim, num_heads, mlp_dim, dropout_rate):
        super().__init__()
        self.norm1 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        # Strides for Convolution as per CVT Paper
        self.q_stride = 1
        self.k_stride = 1
        self.v_stride = 1
        self.kernel_size = 3
        self.in_channels = self.out_channels = embedding_dim
        self.groups = embedding_dim

        # Convolutions for Q K and V . groups is the MOST important thing , as groups  = embedding dimension , 
        # convolution runs on each channel with a 3X3 Kernel, capturing information about neighbors . 
        # Thats why we dont need Positional Embedding , and this is called Local Inductive Bias . 
        
        self.conv_q = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.q_stride,
                                groups = self.groups
                                )

        self.conv_k = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.k_stride,
                                groups = self.groups
                                )

        self.conv_v = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.v_stride,
                                groups = self.groups
                                )
        
        # Each head will process embed_dim/num_heads dimensions so embed_dim%num_heads should be 0 . 
        #batch_first=True: Input shape is (batch, seq, features) → (128, 65, 384)
        # Each head processes: 384 / 12 = 32 dimensions for 12 heads
        # Internally reshaped to: (128, 65, 12, 32) (batch seq heads head_dim) ; Output Concatenated Back to 128 X 65 X 384
        # Pre Norm Architecture ( Norm before addign to Multi Head Attenstion as per VIT Paper)  stabilizes gradients during training, enables training of deeper networks
        #often converges faster than the original "post-norm" design from Attention paper
        self.multiHeadAttn = nn.MultiheadAttention(embed_dim=embedding_dim, num_heads=num_heads, dropout=dropout_rate, batch_first=True)
        # normalizing before each major operation prevents gradient Explosion and Vanishing Gradients during Back Prop
        self.norm2 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        #  position-wise feed-forward network MLP : Applier Non Linear Transformation on the token generated from MHA 
        # MLP applies the same transformation independently to each of the 65 tokens ( 64 Patches + CLS Token ) 
        self.mlp = MLP(embedding_dim, mlp_dim, dropout_rate)

    def forward(self, tensor : torch.Tensor ):
        # Input shape : [128, 65, 384]
      # Remove CLS Token from pensor and perform convolutions on patches only 
        #cls_token = tensor[:, 0:1, :]  # [128, 1, 384]  REMOVE THE CLASS TOKEN 
      #  patches = tensor[:, 1:, :]     # [128, 64, 384]
        patches = tensor
        batch_size, num_patches, embed_dim = patches.shape # 128, 64, 384
        #print("Input Tensor Shape ", tensor.shape)
        #print("batch Size ", batch_size)
        #print("num patches", num_patches)
        #print("Embedding Dim ", embed_dim)
        height = width = np.sqrt(num_patches).astype(np.int64) 
        # Normalize - Layer Norm
        patches = self.norm1(patches)
        #print("Normalized Tensor Shape ", patches.shape)
        patches_transposed = patches.transpose(1,2) #128 64 384 -> 128 384 64
        # Convert to Spacial Format for Convolution
        #print("Transposed Tensor Shape", patches_transposed.shape)
        patches_spacial = patches_transposed.reshape(batch_size, embed_dim, height, width) # [128, 384, 8, 8] 
        
        q = self.conv_q(patches_spacial) # [128, 384, 8, 8]
        k = self.conv_k(patches_spacial) # [128, 384, 8, 8]
        v = self.conv_v(patches_spacial) # [128, 384, 8, 8]
        # back to sequence format for attention - > Flatten and Transpose 
        q = q.flatten(2).transpose(1, 2) # 128, 64, 384
        k = k.flatten(2).transpose(1, 2) # 128, 64, 384
        v = v.flatten(2).transpose(1, 2) # 128, 64, 384 
        #q_with_cls = torch.cat([cls_token, q], dim=1) # [128, 65, 384]
        #k_with_cls = torch.cat([cls_token, k], dim=1) # [128, 65, 384]
        #v_with_cls = torch.cat([cls_token, v], dim=1) # [128, 65, 384]
        #print("q after adding cls token", q_with_cls.shape)
        # q k v for Mutlihead Self Attention come from convolutions unlike VIT
        attn_output, attn_weights = self.multiHeadAttn(query = q , key= k , value = v) 
        tensor = tensor + attn_output # Residual Conenction : Add Original Input to the output from Multi Head Attention 
        tensor = tensor + self.mlp(self.norm2(tensor)) 
        return tensor # Shape 128 X 65 X 384 maintained

# %%
class VisionTransformer(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, num_classes, embedding_dim, depth, num_heads, mlp_dims, dropout_rate):
        super().__init__()
        self.patch_embed = PatchEmbedding(image_size, patch_size, in_channels, embedding_dim)
        self.encoder = nn.Sequential(
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate)
            
        )
        self.norm = nn.LayerNorm(embedding_dim)
        # logits=W⋅x+b , Output is logits of num classes size vector
        self.classification_head = nn.Linear(in_features = embedding_dim, out_features= num_classes) # Linear Classification Head 

    def forward(self, tensor):
        tensor_with_Pos_Embed = self.patch_embed(tensor)
        encoder_output = self.encoder(tensor_with_Pos_Embed)
        normed_encoder_output = self.norm(encoder_output)
        # Global Average Pooling (GAP)
        G_A_P_OP = normed_encoder_output.mean(dim=1) # 
        return self.classification_head(G_A_P_OP) # Output Shape is 128 X 10  ( 10 Classes)

# %%
# Init the Vision transformer Model

model = VisionTransformer(IMAGE_SIZE, PATCH_SIZE,CHANNELS,NUM_CLASSES, EMBEDDING_DIM, DEPTH, NUM_HEADS, MLP_DIM, DROPOUT_RATE ).to(device)

# %%
model
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbedding(
#     (projection): Conv2d(3, 384, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (encoder): Sequential(
#     (0): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (7): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (8): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (9): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (10): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (11): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classification_head): Linear(in_features=384, out_features=10, bias=True)
# )

# %%
# IMAGE TRANSFORM and dataset prep

# %%
cifar10_mean = [0.4914, 0.4822, 0.4465]
cifar10_std = [0.2023, 0.1994, 0.2010]

train_transformer = transforms.Compose([
transforms.RandomCrop(32, padding=4),    
transforms.RandomHorizontalFlip(),
transforms.RandAugment(num_ops=2, magnitude=9),
transforms.ToTensor(),
transforms.Normalize(cifar10_mean, cifar10_std),
    
])

train_dataset = datasets.CIFAR10(root="cifar10_data", train=True, download = True, transform = train_transformer)

# %%
train_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: cifar10_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                RandAugment(num_ops=2, magnitude=9, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#                ToTensor()
#                Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#            )

# %%
# Load Testing Data 

test_transformer = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize(cifar10_mean, cifar10_std)
])

test_dataset = datasets.CIFAR10(root="cifar10_data", train=False, download = True, transform = test_transformer)

# %%
test_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: cifar10_data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#            )

# %%
#DataLoaders

dataloader_train = DataLoader(train_dataset, batch_size=128, shuffle=True)
dataloader_test = DataLoader(test_dataset, batch_size=128, shuffle=False)

print(f"TRAIN DATALOADER : {len(dataloader_train)} batches")
print(f"TEST DATALOADER : {len(dataloader_test)} batches")
# Out:
# TRAIN DATALOADER : 391 batches
# TEST DATALOADER : 79 batches

# %%
# Training

def train(model, loader : DataLoader, optimizer, loss_function):
    model.train()
    correct, total_loss = 0, 0  
    for img_batch, labels in loader:
        img_batch = img_batch.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        output = model(img_batch)
        loss = loss_function(output, labels)
        loss.backward() # Back Prop 
        optimizer.step() # gradient Descent
        total_loss+= loss.item() * img_batch.size(0)
        correct+= (output.argmax(1)==labels).sum().item()
    return total_loss/len(loader.dataset) , correct/len(loader.dataset)

# %%
# Evaluation
def evaluate_model(model, loader : DataLoader):
    model.eval()
    correct = 0
    with torch.inference_mode():
        for img_batch, labels in loader:
            img_batch = img_batch.to(device)
            labels = labels.to(device)
            output = model(img_batch)
            predictions = output.argmax(dim=1)
            correct+= (predictions==labels).sum().item()
        return correct/len(loader.dataset)

# %%
#from tqdm.auto import tqdm

# %%
from lion_pytorch import Lion

train_accuracies, test_accuracies = [], []
EPOCHS=100
# Cross Entropy Loss and AdamW Optimizer 
loss_function = nn.CrossEntropyLoss()
#optimizer_lion = Lion(model.parameters(), lr=3e-5, weight_decay=0.1)


optimizer = optim.AdamW(params=model.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.999), weight_decay=0.01)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)
 
for epoch in range(EPOCHS):
    train_loss, train_acc = train(model, dataloader_train, optimizer, loss_function)
    test_acc = evaluate_model(model, dataloader_test)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch : {epoch+1} of {EPOCHS}, Train Loss : {train_loss:.4f} , Train Accuracy : {train_acc:.4f}, Test Accuracy : {test_acc:.4f}")
    scheduler.step()
# Out:
# Epoch : 1 of 100, Train Loss : 1.7768 , Train Accuracy : 0.3471, Test Accuracy : 0.5426
# Epoch : 2 of 100, Train Loss : 1.3191 , Train Accuracy : 0.5279, Test Accuracy : 0.6246
# Epoch : 3 of 100, Train Loss : 1.1184 , Train Accuracy : 0.6047, Test Accuracy : 0.6715
# Epoch : 4 of 100, Train Loss : 1.0012 , Train Accuracy : 0.6494, Test Accuracy : 0.7106
# Epoch : 5 of 100, Train Loss : 0.9111 , Train Accuracy : 0.6831, Test Accuracy : 0.7367
# Epoch : 6 of 100, Train Loss : 0.8418 , Train Accuracy : 0.7073, Test Accuracy : 0.7556
# Epoch : 7 of 100, Train Loss : 0.7904 , Train Accuracy : 0.7230, Test Accuracy : 0.7665
# Epoch : 8 of 100, Train Loss : 0.7377 , Train Accuracy : 0.7427, Test Accuracy : 0.7931
# Epoch : 9 of 100, Train Loss : 0.6990 , Train Accuracy : 0.7575, Test Accuracy : 0.7994
# Epoch : 10 of 100, Train Loss : 0.6685 , Train Accuracy : 0.7671, Test Accuracy : 0.8046
# Epoch : 11 of 100, Train Loss : 0.6375 , Train Accuracy : 0.7775, Test Accuracy : 0.8108
# Epoch : 12 of 100, Train Loss : 0.6106 , Train Accuracy : 0.7851, Test Accuracy : 0.8273
# Epoch : 13 of 100, Train Loss : 0.5950 , Train Accuracy : 0.7935, Test Accuracy : 0.8248
# Epoch : 14 of 100, Train Loss : 0.5702 , Train Accuracy : 0.8030, Test Accuracy : 0.8269
# Epoch : 15 of 100, Train Loss : 0.5486 , Train Accuracy : 0.8074, Test Accuracy : 0.8380
# Epoch : 16 of 100, Train Loss : 0.5275 , Train Accuracy : 0.8159, Test Accuracy : 0.8496
# Epoch : 17 of 100, Train Loss : 0.5104 , Train Accuracy : 0.8225, Test Accuracy : 0.8533
# Epoch : 18 of 100, Train Loss : 0.4969 , Train Accuracy : 0.8255, Test Accuracy : 0.8474
# Epoch : 19 of 100, Train Loss : 0.4781 , Train Accuracy : 0.8328, Test Accuracy : 0.8502
# Epoch : 20 of 100, Train Loss : 0.4669 , Train Accuracy : 0.8392, Test Accuracy : 0.8582
# Epoch : 21 of 100, Train Loss : 0.4516 , Train Accuracy : 0.8420, Test Accuracy : 0.8580
# Epoch : 22 of 100, Train Loss : 0.4371 , Train Accuracy : 0.8468, Test Accuracy : 0.8600
# Epoch : 23 of 100, Train Loss : 0.4270 , Train Accuracy : 0.8506, Test Accuracy : 0.8651
# Epoch : 24 of 100, Train Loss : 0.4136 , Train Accuracy : 0.8545, Test Accuracy : 0.8651
# Epoch : 25 of 100, Train Loss : 0.3983 , Train Accuracy : 0.8609, Test Accuracy : 0.8671
# Epoch : 26 of 100, Train Loss : 0.3884 , Train Accuracy : 0.8650, Test Accuracy : 0.8690
# Epoch : 27 of 100, Train Loss : 0.3773 , Train Accuracy : 0.8690, Test Accuracy : 0.8697
# Epoch : 28 of 100, Train Loss : 0.3709 , Train Accuracy : 0.8706, Test Accuracy : 0.8751
# Epoch : 29 of 100, Train Loss : 0.3562 , Train Accuracy : 0.8756, Test Accuracy : 0.8673
# Epoch : 30 of 100, Train Loss : 0.3451 , Train Accuracy : 0.8793, Test Accuracy : 0.8839
# Epoch : 31 of 100, Train Loss : 0.3359 , Train Accuracy : 0.8813, Test Accuracy : 0.8814
# Epoch : 32 of 100, Train Loss : 0.3319 , Train Accuracy : 0.8823, Test Accuracy : 0.8821
# Epoch : 33 of 100, Train Loss : 0.3144 , Train Accuracy : 0.8904, Test Accuracy : 0.8833
# Epoch : 34 of 100, Train Loss : 0.3080 , Train Accuracy : 0.8924, Test Accuracy : 0.8804
# Epoch : 35 of 100, Train Loss : 0.2992 , Train Accuracy : 0.8943, Test Accuracy : 0.8798
# Epoch : 36 of 100, Train Loss : 0.2916 , Train Accuracy : 0.8981, Test Accuracy : 0.8805
# Epoch : 37 of 100, Train Loss : 0.2841 , Train Accuracy : 0.9004, Test Accuracy : 0.8874
# Epoch : 38 of 100, Train Loss : 0.2781 , Train Accuracy : 0.9030, Test Accuracy : 0.8859
# Epoch : 39 of 100, Train Loss : 0.2712 , Train Accuracy : 0.9047, Test Accuracy : 0.8837
# Epoch : 40 of 100, Train Loss : 0.2608 , Train Accuracy : 0.9085, Test Accuracy : 0.8894
# Epoch : 41 of 100, Train Loss : 0.2561 , Train Accuracy : 0.9103, Test Accuracy : 0.8879
# Epoch : 42 of 100, Train Loss : 0.2477 , Train Accuracy : 0.9132, Test Accuracy : 0.8940
# Epoch : 43 of 100, Train Loss : 0.2392 , Train Accuracy : 0.9161, Test Accuracy : 0.8888
# Epoch : 44 of 100, Train Loss : 0.2345 , Train Accuracy : 0.9162, Test Accuracy : 0.8908
# Epoch : 45 of 100, Train Loss : 0.2298 , Train Accuracy : 0.9192, Test Accuracy : 0.8891
# Epoch : 46 of 100, Train Loss : 0.2258 , Train Accuracy : 0.9204, Test Accuracy : 0.8989
# Epoch : 47 of 100, Train Loss : 0.2136 , Train Accuracy : 0.9251, Test Accuracy : 0.8932
# Epoch : 48 of 100, Train Loss : 0.2161 , Train Accuracy : 0.9239, Test Accuracy : 0.8912
# Epoch : 49 of 100, Train Loss : 0.2072 , Train Accuracy : 0.9278, Test Accuracy : 0.8972
# Epoch : 50 of 100, Train Loss : 0.1971 , Train Accuracy : 0.9314, Test Accuracy : 0.8921
# Epoch : 51 of 100, Train Loss : 0.1910 , Train Accuracy : 0.9337, Test Accuracy : 0.8953
# Epoch : 52 of 100, Train Loss : 0.1853 , Train Accuracy : 0.9345, Test Accuracy : 0.8948
# Epoch : 53 of 100, Train Loss : 0.1811 , Train Accuracy : 0.9369, Test Accuracy : 0.8949
# Epoch : 54 of 100, Train Loss : 0.1750 , Train Accuracy : 0.9393, Test Accuracy : 0.8994
# Epoch : 55 of 100, Train Loss : 0.1721 , Train Accuracy : 0.9407, Test Accuracy : 0.8995
# Epoch : 56 of 100, Train Loss : 0.1667 , Train Accuracy : 0.9413, Test Accuracy : 0.8983
# Epoch : 57 of 100, Train Loss : 0.1631 , Train Accuracy : 0.9426, Test Accuracy : 0.8974
# Epoch : 58 of 100, Train Loss : 0.1606 , Train Accuracy : 0.9437, Test Accuracy : 0.8984
# Epoch : 59 of 100, Train Loss : 0.1528 , Train Accuracy : 0.9476, Test Accuracy : 0.8998
# Epoch : 60 of 100, Train Loss : 0.1466 , Train Accuracy : 0.9490, Test Accuracy : 0.8976
# Epoch : 61 of 100, Train Loss : 0.1463 , Train Accuracy : 0.9480, Test Accuracy : 0.9011
# Epoch : 62 of 100, Train Loss : 0.1394 , Train Accuracy : 0.9521, Test Accuracy : 0.9032
# Epoch : 63 of 100, Train Loss : 0.1359 , Train Accuracy : 0.9530, Test Accuracy : 0.9033
# Epoch : 64 of 100, Train Loss : 0.1351 , Train Accuracy : 0.9532, Test Accuracy : 0.9008
# Epoch : 65 of 100, Train Loss : 0.1253 , Train Accuracy : 0.9563, Test Accuracy : 0.9044
# Epoch : 66 of 100, Train Loss : 0.1227 , Train Accuracy : 0.9567, Test Accuracy : 0.9039
# Epoch : 67 of 100, Train Loss : 0.1242 , Train Accuracy : 0.9565, Test Accuracy : 0.9034
# Epoch : 68 of 100, Train Loss : 0.1214 , Train Accuracy : 0.9575, Test Accuracy : 0.9050
# Epoch : 69 of 100, Train Loss : 0.1145 , Train Accuracy : 0.9605, Test Accuracy : 0.9021
# Epoch : 70 of 100, Train Loss : 0.1163 , Train Accuracy : 0.9600, Test Accuracy : 0.9012
# Epoch : 71 of 100, Train Loss : 0.1103 , Train Accuracy : 0.9613, Test Accuracy : 0.9059
# Epoch : 72 of 100, Train Loss : 0.1062 , Train Accuracy : 0.9640, Test Accuracy : 0.9042
# Epoch : 73 of 100, Train Loss : 0.1053 , Train Accuracy : 0.9633, Test Accuracy : 0.9052
# Epoch : 74 of 100, Train Loss : 0.1017 , Train Accuracy : 0.9651, Test Accuracy : 0.9017
# Epoch : 75 of 100, Train Loss : 0.0960 , Train Accuracy : 0.9669, Test Accuracy : 0.9031
# Epoch : 76 of 100, Train Loss : 0.0984 , Train Accuracy : 0.9663, Test Accuracy : 0.9090
# Epoch : 77 of 100, Train Loss : 0.0945 , Train Accuracy : 0.9676, Test Accuracy : 0.9065
# Epoch : 78 of 100, Train Loss : 0.0903 , Train Accuracy : 0.9694, Test Accuracy : 0.9062
# Epoch : 79 of 100, Train Loss : 0.0915 , Train Accuracy : 0.9689, Test Accuracy : 0.9078
# Epoch : 80 of 100, Train Loss : 0.0868 , Train Accuracy : 0.9703, Test Accuracy : 0.9064
# Epoch : 81 of 100, Train Loss : 0.0881 , Train Accuracy : 0.9698, Test Accuracy : 0.9089
# Epoch : 82 of 100, Train Loss : 0.0833 , Train Accuracy : 0.9712, Test Accuracy : 0.9082
# Epoch : 83 of 100, Train Loss : 0.0840 , Train Accuracy : 0.9715, Test Accuracy : 0.9093
# Epoch : 84 of 100, Train Loss : 0.0824 , Train Accuracy : 0.9724, Test Accuracy : 0.9087
# Epoch : 85 of 100, Train Loss : 0.0832 , Train Accuracy : 0.9710, Test Accuracy : 0.9094
# Epoch : 86 of 100, Train Loss : 0.0788 , Train Accuracy : 0.9734, Test Accuracy : 0.9091
# Epoch : 87 of 100, Train Loss : 0.0777 , Train Accuracy : 0.9735, Test Accuracy : 0.9112
# Epoch : 88 of 100, Train Loss : 0.0780 , Train Accuracy : 0.9733, Test Accuracy : 0.9110
# Epoch : 89 of 100, Train Loss : 0.0764 , Train Accuracy : 0.9743, Test Accuracy : 0.9110
# Epoch : 90 of 100, Train Loss : 0.0737 , Train Accuracy : 0.9752, Test Accuracy : 0.9091
# Epoch : 91 of 100, Train Loss : 0.0758 , Train Accuracy : 0.9739, Test Accuracy : 0.9103
# Epoch : 92 of 100, Train Loss : 0.0713 , Train Accuracy : 0.9759, Test Accuracy : 0.9102
# Epoch : 93 of 100, Train Loss : 0.0763 , Train Accuracy : 0.9736, Test Accuracy : 0.9098
# Epoch : 94 of 100, Train Loss : 0.0746 , Train Accuracy : 0.9743, Test Accuracy : 0.9089
# Epoch : 95 of 100, Train Loss : 0.0701 , Train Accuracy : 0.9757, Test Accuracy : 0.9098
# Epoch : 96 of 100, Train Loss : 0.0732 , Train Accuracy : 0.9752, Test Accuracy : 0.9093
# Epoch : 97 of 100, Train Loss : 0.0737 , Train Accuracy : 0.9749, Test Accuracy : 0.9093
# Epoch : 98 of 100, Train Loss : 0.0716 , Train Accuracy : 0.9756, Test Accuracy : 0.9098
# Epoch : 99 of 100, Train Loss : 0.0727 , Train Accuracy : 0.9753, Test Accuracy : 0.9099
# Epoch : 100 of 100, Train Loss : 0.0740 , Train Accuracy : 0.9752, Test Accuracy : 0.9099

# %%
plt.plot(train_accuracies, label = "Train Accuracy")
plt.plot(test_accuracies, label = "Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Train and Test Accuracies, Conv Vision Transformer  ")
plt.savefig("ConvVisionTransformer-NoCLSToken-GAP",  dpi=300)
plt.show()

# %%
torch.save(model, 'ConvVisionTransformer-NoCLSToken-GAP.pth')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score
from torchmetrics.classification import AUROC

model = torch.load('ConvVisionTransformer-NoCLSToken-GAP.pth', weights_only=False)

def test_model(model, loader : DataLoader):
    model.eval()
    correct = 0
    all_labels = []
    all_predictions = []
    with torch.inference_mode():
        for img_batch, labels in loader:
            img_batch = img_batch.to(device)
            labels = labels.to(device)
            output = model(img_batch)
            predictions = output.argmax(dim=1)
            correct+= (predictions==labels).sum().item()
            all_labels.extend(labels.to("cpu").numpy())
            all_predictions.extend(predictions.to("cpu").numpy())
        return correct/len(loader.dataset), all_labels, all_predictions   

test_accuracy, all_labels, all_predictions = test_model(model, dataloader_test)
        
cm = confusion_matrix(all_labels, all_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig("ConvVisionTransformer-NoCLSToken-GAPConfusionMatrix.png",  dpi=300)
plt.show()

precision = precision_score(all_labels, all_predictions, average='weighted')
recall = recall_score(all_labels, all_predictions, average='weighted')
f1 = f1_score(all_labels, all_predictions, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# Precision: 0.91
# Recall:    0.91
# F1 Score:  0.91

# %%
grid_size = 5
fig, axes = plt.subplots(grid_size, grid_size, figsize = (9, 9))
classes = test_dataset.classes
model = torch.load('ConvVisionTransformer-NoCLSToken-GAP.pth', weights_only=False)

model.eval()

for i in range(grid_size):
    for j in range(grid_size):
        index = random.randint(0, len(test_dataset) -1)
        img , correct_label = test_dataset[index]
        input_tensor = img.unsqueeze(dim=0).to(device)
        with torch.inference_mode():
            output = model(input_tensor)
            _, predicted = torch.max(output.data,1)
        img = img / 2 + 0.5 # denormalizing images to plot 
        nump_img = img.to("cpu")
        axes[i, j].imshow(np.transpose(nump_img, (1,2,0)))
        correct_match = classes[correct_label] == classes[predicted.item()]
        axes[i, j].set_title(f"Actual Label :  {classes[correct_label]} \n Predicted Label :  {classes[predicted.item()]},]" , fontsize = 10)
        axes[i, j].axis("off")
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6009598..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.28806478..1.4837258].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6369933..1.6213496].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.36495757..1.7110282].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.6232319].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49363476..1.4081155].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56192076..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51099133..1.3110672].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.61069655..1.7305385].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65012693..1.631042].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.699294..1.8476002].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.59822345..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.57145953..1.5451907].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.060121536..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.63046..1.757044].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6402935..1.7500488].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65996027..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5594536..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.63046..1.2870574].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.699294..1.6427422].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.62730074..1.1948814].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6796272..1.8085796].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65012693..1.5438099].
