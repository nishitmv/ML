# %%
from torch import optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np 
import random
import torchvision 
import torch.nn.functional as functional

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
# !nvidia-smi
# Out:
# Sat Nov 15 12:42:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.88                 Driver Version: 580.88         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 34%   31C    P8            N/A  /  115W |    3025MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2016    C+G   C:\Windows\System32\dwm.exe           N/A      |
# |    0   N/A  N/A            2940      C   ...tsML\.venv\Scripts\python.exe      N/A      |
# |    0   N/A  N/A            3528    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A            5512    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A            6040    C+G   ...x64__8wekyb3d8bbwe\Photos.exe      N/A      |
# |    0   N/A  N/A            8624    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           10676    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           11168    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           11208    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           11576    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           11968    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           12544    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           14248    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           15136    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           15316    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15824    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           15832    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           15952    C+G   ...x64__8wekyb3d8bbwe\Photos.exe      N/A      |
# |    0   N/A  N/A           16844    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           17696    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20064    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           21284    C+G   ...yApp\MicrosoftSecurityApp.exe      N/A      |
# |    0   N/A  N/A           22060    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22188    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           23216    C+G   ...r\Mystic Light\LEDKeeper2.exe      N/A      |
# |    0   N/A  N/A           24192    C+G   ...ams\Perplexity\Perplexity.exe      N/A      |
# |    0   N/A  N/A           25992    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           27040    C+G   ...abra\Direct6\jabra-direct.exe      N/A      |
# |    0   N/A  N/A           27380    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           28520    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           28972    C+G   ...__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A           30696    C+G   ...64__8wekyb3d8bbwe\Copilot.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Setting uniform seed

# %%
torch.manual_seed(32)
torch.cuda.manual_seed(32)
random.seed(42)

# %%
# Set Hyper Parameters

# %%
BATCH_SIZE = 128
EPOCHS = 10
LEARNING_RATE = 3e-4
LION_LEARNING_RATE= 1e-4
PATCH_SIZE = 4
NUM_CLASSES=10 # for CIFAR
IMAGE_SIZE = 32
CHANNELS = 3
EMBEDDING_DIM = 384
NUM_HEADS = 8
DEPTH = 6 # Number of Transformer Encoder Blocks
MLP_DIM = 512
DROPOUT_RATE=0.1

# %%
# IMAGE TRANSFORM and dataset prep

# %%
cifar10_mean = [0.4914, 0.4822, 0.4465]
cifar10_std = [0.2023, 0.1994, 0.2010]

train_transformer = transforms.Compose([
transforms.RandomCrop(32, padding=4),    
transforms.RandomHorizontalFlip(),
transforms.RandAugment(num_ops=2, magnitude=9),
transforms.ToTensor(),
transforms.Normalize(cifar10_mean, cifar10_std),
    
])

train_dataset = datasets.CIFAR10(root="cifar10_data", train=True, download = True, transform = train_transformer)

# %%
train_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: cifar10_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                RandAugment(num_ops=2, magnitude=9, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#                ToTensor()
#                Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#            )

# %%
# Load Testing Data 

test_transformer = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize(cifar10_mean, cifar10_std)
])

test_dataset = datasets.CIFAR10(root="cifar10_data", train=False, download = True, transform = test_transformer)

# %%
test_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: cifar10_data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#            )

# %%
#DataLoaders

dataloader_train = DataLoader(train_dataset, batch_size=128, shuffle=True)
dataloader_test = DataLoader(test_dataset, batch_size=128, shuffle=False)

print(f"TRAIN DATALOADER : {len(dataloader_train)} batches")
print(f"TEST DATALOADER : {len(dataloader_test)} batches")
# Out:
# TRAIN DATALOADER : 391 batches
# TEST DATALOADER : 79 batches

# %%
#Patch Embedding , Create patches and return Tensor of Dimansion :  128 X 65 X 128 : 128 images 65 tokens(patches + CLS) per image, 
#128d per token (128d vector per patch)

class PatchEmbedding(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, embedding_dim):
        super().__init__()
        self.patch_size = patch_size
       # IMPORTANT : Use Convolution 2d as Projection Layer as its more efficient than a Linear Layer . The paper actually Mentions a Linear Layer . 
       # kernel and stride are assigned to patch size as we want patches and not overlaps  
        self.projection = nn.Conv2d(in_channels = in_channels, out_channels = embedding_dim, kernel_size = patch_size , stride=patch_size)
       # For square images number of patches is (image size/patch size) ^2         
        num_patches = (image_size//patch_size)**2
        #The CLS token (classification token) in Vision Transformers is a special learnable parameter that serves as a placeholder
        #for aggregating global information from all image patches for classification tasks
        self.cls_token = nn.Parameter(torch.randn(1, 1, embedding_dim)) # Random to begin with 
        self.pos_embed = nn.Parameter(torch.randn(1, num_patches + 1, embedding_dim))
        #print(self.cls_token)
        #print(self.pos_embed)   
                                      
    def forward(self, tensor: torch.Tensor):
            # Tensor is 128 X 3 X 32 X 32 ( 3 , 32, 32 is the image 32X32 with 3 channels) 
            batch_size = tensor.size(0) # Get Batch Size 
            projected_tensor = self.projection(tensor)  # Each patch becomes 128d feature vector Tensor is now : 128*128*8*8
            flattened_tensor = projected_tensor.flatten(2) # flatten 128*128*8*8 to 128*128*64
            transposed_tensor = flattened_tensor.transpose(1,2) # swap to : 128 *64*128 converts tensor to format (batch_size, sequence_length, embedding_dim) by swapping dims: 
            cls_token = self.cls_token.expand(batch_size, -1, -1) # cls_token is replicated to all 128 images in the batch 
            tensor_with_cls_token = torch.cat((cls_token, transposed_tensor), dim=1)   # CLS Token in position 0 , Position 1 to 64 image patches
            tensor_with_Pos_Embed = tensor_with_cls_token + self.pos_embed 
            return tensor_with_Pos_Embed # 128 X 65 X 128 : 128 images 65 tokens per image ( CLS token + 64 Patches), 128d representation of each token

# %%
class MLP(nn.Module):
    def __init__(self, in_features, hidden_features, dropout_rate):
        super().__init__()
        self.fc1 = nn.Linear(in_features=in_features, out_features=hidden_features)
        self.fc2 = nn.Linear(in_features=hidden_features, out_features=in_features)
        self.dropout = nn.Dropout(dropout_rate)
    def forward(self, tensor): # EXPAND ACTIVATE PROJECT BACK , Maintains original Dimensions 
        tensor = self.fc1(tensor)  # Tensor is  128 X 65 X 128 , output is 128 X 65 X 512
        tensor = self.dropout(functional.gelu(tensor)) # Input & output is 128 X 65 X 512 , Activation Function : Gaussian Error Linear Unit
        tensor = self.dropout(self.fc2(tensor)) # input is 128 X 65 X 512 and output is 128 X 65 X 128
        return tensor

# %%
class TransformerEncoder(nn.Module): 
    def __init__(self, embedding_dim, num_heads, mlp_dim, dropout_rate):
        super().__init__()
        self.norm1 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        # Each head will process embed_dim/num_heads dimensions so embed_dim%num_heads should be 0 . 
        #batch_first=True: Input shape is (batch, seq, features) → (128, 65, 128)
        # Each head processes: 384 / 12 = 32 dimensions for 8 heads
        # Internally reshaped to: (128, 65, 8, 16) (batch seq heads head_dim) ; Output Concatenated Back to 128 X 65 X 128
        # Pre Norm Architecture ( Norm before addign to Multi Head Attenstion as per VIT Paper)  stabilizes gradients during training, enables training of deeper networks
        #often converges faster than the original "post-norm" design from Attention paper
        self.multiHeadAttn = nn.MultiheadAttention(embed_dim=embedding_dim, num_heads=num_heads, dropout=dropout_rate, batch_first=True)
        # normalizing before each major operation prevents gradient Explosion and Vanishing Gradients during Back Prop
        self.norm2 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        #  position-wise feed-forward network MLP : Applier Non Linear Transformation on the token generated from MHA 
        # MLP applies the same transformation independently to each of the 65 tokens ( 64 Patches + CLS Token ) 
        self.mlp = MLP(embedding_dim, mlp_dim, dropout_rate)

    def forward(self, tensor):
        # q k v for Mutlihead Self Attention come from the same source i.e the normalized tensor 
        attn_output, attn_weights = self.multiHeadAttn(query = self.norm1(tensor), key= self.norm1(tensor), value = self.norm1(tensor)) 
        tensor = tensor + attn_output # Residual Conenction : Add Original Input to the output from Multi Head Attention 
        tensor = tensor + self.mlp(self.norm2(tensor))
        return tensor # Shape 128 X 65 X 128 maintained

# %%
class VisionTransformer(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, num_classes, embedding_dim, depth, num_heads, mlp_dims, dropout_rate):
        super().__init__()
        self.patch_embed = PatchEmbedding(image_size, patch_size, in_channels, embedding_dim)
        self.encoder = nn.Sequential(
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            TransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate)
            
        )
        self.norm = nn.LayerNorm(embedding_dim)
        # logits=W⋅x+b , Output is logits of num classes size vector
        self.classification_head = nn.Linear(in_features = embedding_dim, out_features= num_classes) # Linear Classification Head 

    def forward(self, tensor):
        tensor_with_Pos_Embed = self.patch_embed(tensor)
        encoder_output = self.encoder(tensor_with_Pos_Embed)
        normed_encoder_output = self.norm(encoder_output)
        cls_token = normed_encoder_output[:, 0] # Token at position 0 is the CLS TOKEN with Dimension 128 X 128 
        # Coz CLS Token was PREPENDED at position 0 
        return self.classification_head(cls_token) # Output Shape is 128 X 10  ( 10 Classes)

# %%
# Init the Vision transformer Model

model = VisionTransformer(IMAGE_SIZE, PATCH_SIZE,CHANNELS,NUM_CLASSES, EMBEDDING_DIM, DEPTH, NUM_HEADS, MLP_DIM, DROPOUT_RATE ).to(device)

# %%
model
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbedding(
#     (projection): Conv2d(3, 384, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (encoder): Sequential(
#     (0): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (7): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (8): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (9): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (10): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (11): TransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classification_head): Linear(in_features=384, out_features=10, bias=True)
# )

# %%
# Training

def train(model, loader : DataLoader, optimizer, loss_function):
    model.train()
    correct, total_loss = 0, 0  
    for img_batch, labels in loader:
        img_batch = img_batch.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        output = model(img_batch)
        loss = loss_function(output, labels)
        loss.backward() # Back Prop 
        optimizer.step() # gradient Descent
        total_loss+= loss.item() * img_batch.size(0)
        correct+= (output.argmax(1)==labels).sum().item()
    return total_loss/len(loader.dataset) , correct/len(loader.dataset)

# %%
# Evaluation
def evaluate_model(model, loader : DataLoader):
    model.eval()
    correct = 0
    with torch.inference_mode():
        for img_batch, labels in loader:
            img_batch = img_batch.to(device)
            labels = labels.to(device)
            output = model(img_batch)
            predictions = output.argmax(dim=1)
            correct+= (predictions==labels).sum().item()
        return correct/len(loader.dataset)

# %%
from tqdm.auto import tqdm

# %%
train_accuracies, test_accuracies = [], []
EPOCHS=100
# Cross Entropy Loss and AdamW Optimizer 
loss_function = nn.CrossEntropyLoss()
optimizer = optim.AdamW(params=model.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.999), weight_decay=0.01)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

for epoch in range(EPOCHS):
    train_loss, train_acc = train(model, dataloader_train, optimizer, loss_function)
    test_acc = evaluate_model(model, dataloader_test)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch : {epoch+1} of {EPOCHS}, Train Loss : {train_loss:.4f} , Train Accuracy : {train_acc:.4f}, Test Accuracy : {test_acc:.4f}")
    scheduler.step()
# Out:
# Epoch : 1 of 100, Train Loss : 1.9237 , Train Accuracy : 0.2922, Test Accuracy : 0.4565
# Epoch : 2 of 100, Train Loss : 1.6143 , Train Accuracy : 0.4110, Test Accuracy : 0.5293
# Epoch : 3 of 100, Train Loss : 1.4846 , Train Accuracy : 0.4621, Test Accuracy : 0.5439
# Epoch : 4 of 100, Train Loss : 1.4031 , Train Accuracy : 0.4943, Test Accuracy : 0.5557
# Epoch : 5 of 100, Train Loss : 1.3390 , Train Accuracy : 0.5177, Test Accuracy : 0.5870
# Epoch : 6 of 100, Train Loss : 1.2897 , Train Accuracy : 0.5368, Test Accuracy : 0.5969
# Epoch : 7 of 100, Train Loss : 1.2332 , Train Accuracy : 0.5587, Test Accuracy : 0.6242
# Epoch : 8 of 100, Train Loss : 1.1951 , Train Accuracy : 0.5727, Test Accuracy : 0.6534
# Epoch : 9 of 100, Train Loss : 1.1516 , Train Accuracy : 0.5912, Test Accuracy : 0.6748
# Epoch : 10 of 100, Train Loss : 1.1157 , Train Accuracy : 0.6014, Test Accuracy : 0.6701
# Epoch : 11 of 100, Train Loss : 1.0776 , Train Accuracy : 0.6147, Test Accuracy : 0.6748
# Epoch : 12 of 100, Train Loss : 1.0475 , Train Accuracy : 0.6272, Test Accuracy : 0.6996
# Epoch : 13 of 100, Train Loss : 1.0158 , Train Accuracy : 0.6387, Test Accuracy : 0.7065
# Epoch : 14 of 100, Train Loss : 0.9967 , Train Accuracy : 0.6445, Test Accuracy : 0.7038
# Epoch : 15 of 100, Train Loss : 0.9653 , Train Accuracy : 0.6585, Test Accuracy : 0.7201
# Epoch : 16 of 100, Train Loss : 0.9429 , Train Accuracy : 0.6645, Test Accuracy : 0.7173
# Epoch : 17 of 100, Train Loss : 0.9191 , Train Accuracy : 0.6739, Test Accuracy : 0.7277
# Epoch : 18 of 100, Train Loss : 0.9007 , Train Accuracy : 0.6821, Test Accuracy : 0.7268
# Epoch : 19 of 100, Train Loss : 0.8739 , Train Accuracy : 0.6921, Test Accuracy : 0.7439
# Epoch : 20 of 100, Train Loss : 0.8622 , Train Accuracy : 0.6949, Test Accuracy : 0.7519
# Epoch : 21 of 100, Train Loss : 0.8356 , Train Accuracy : 0.7059, Test Accuracy : 0.7519
# Epoch : 22 of 100, Train Loss : 0.8196 , Train Accuracy : 0.7116, Test Accuracy : 0.7610
# Epoch : 23 of 100, Train Loss : 0.7919 , Train Accuracy : 0.7203, Test Accuracy : 0.7569
# Epoch : 24 of 100, Train Loss : 0.7816 , Train Accuracy : 0.7263, Test Accuracy : 0.7727
# Epoch : 25 of 100, Train Loss : 0.7623 , Train Accuracy : 0.7296, Test Accuracy : 0.7680
# Epoch : 26 of 100, Train Loss : 0.7330 , Train Accuracy : 0.7409, Test Accuracy : 0.7680
# Epoch : 27 of 100, Train Loss : 0.7228 , Train Accuracy : 0.7455, Test Accuracy : 0.7771
# Epoch : 28 of 100, Train Loss : 0.7037 , Train Accuracy : 0.7503, Test Accuracy : 0.7843
# Epoch : 29 of 100, Train Loss : 0.6917 , Train Accuracy : 0.7562, Test Accuracy : 0.7951
# Epoch : 30 of 100, Train Loss : 0.6654 , Train Accuracy : 0.7663, Test Accuracy : 0.7986
# Epoch : 31 of 100, Train Loss : 0.6561 , Train Accuracy : 0.7691, Test Accuracy : 0.8107
# Epoch : 32 of 100, Train Loss : 0.6406 , Train Accuracy : 0.7736, Test Accuracy : 0.7994
# Epoch : 33 of 100, Train Loss : 0.6261 , Train Accuracy : 0.7781, Test Accuracy : 0.8101
# Epoch : 34 of 100, Train Loss : 0.6024 , Train Accuracy : 0.7856, Test Accuracy : 0.8121
# Epoch : 35 of 100, Train Loss : 0.5941 , Train Accuracy : 0.7914, Test Accuracy : 0.8225
# Epoch : 36 of 100, Train Loss : 0.5783 , Train Accuracy : 0.7977, Test Accuracy : 0.8173
# Epoch : 37 of 100, Train Loss : 0.5642 , Train Accuracy : 0.8028, Test Accuracy : 0.8209
# Epoch : 38 of 100, Train Loss : 0.5493 , Train Accuracy : 0.8060, Test Accuracy : 0.8237
# Epoch : 39 of 100, Train Loss : 0.5392 , Train Accuracy : 0.8099, Test Accuracy : 0.8311
# Epoch : 40 of 100, Train Loss : 0.5283 , Train Accuracy : 0.8126, Test Accuracy : 0.8262
# Epoch : 41 of 100, Train Loss : 0.5085 , Train Accuracy : 0.8197, Test Accuracy : 0.8348
# Epoch : 42 of 100, Train Loss : 0.5024 , Train Accuracy : 0.8229, Test Accuracy : 0.8330
# Epoch : 43 of 100, Train Loss : 0.4922 , Train Accuracy : 0.8262, Test Accuracy : 0.8387
# Epoch : 44 of 100, Train Loss : 0.4796 , Train Accuracy : 0.8318, Test Accuracy : 0.8389
# Epoch : 45 of 100, Train Loss : 0.4678 , Train Accuracy : 0.8343, Test Accuracy : 0.8385
# Epoch : 46 of 100, Train Loss : 0.4533 , Train Accuracy : 0.8395, Test Accuracy : 0.8470
# Epoch : 47 of 100, Train Loss : 0.4422 , Train Accuracy : 0.8449, Test Accuracy : 0.8423
# Epoch : 48 of 100, Train Loss : 0.4292 , Train Accuracy : 0.8482, Test Accuracy : 0.8421
# Epoch : 49 of 100, Train Loss : 0.4212 , Train Accuracy : 0.8506, Test Accuracy : 0.8465
# Epoch : 50 of 100, Train Loss : 0.4121 , Train Accuracy : 0.8544, Test Accuracy : 0.8478
# Epoch : 51 of 100, Train Loss : 0.3935 , Train Accuracy : 0.8593, Test Accuracy : 0.8551
# Epoch : 52 of 100, Train Loss : 0.3925 , Train Accuracy : 0.8606, Test Accuracy : 0.8526
# Epoch : 53 of 100, Train Loss : 0.3765 , Train Accuracy : 0.8674, Test Accuracy : 0.8580
# Epoch : 54 of 100, Train Loss : 0.3676 , Train Accuracy : 0.8708, Test Accuracy : 0.8515
# Epoch : 55 of 100, Train Loss : 0.3561 , Train Accuracy : 0.8744, Test Accuracy : 0.8597
# Epoch : 56 of 100, Train Loss : 0.3501 , Train Accuracy : 0.8763, Test Accuracy : 0.8572
# Epoch : 57 of 100, Train Loss : 0.3417 , Train Accuracy : 0.8796, Test Accuracy : 0.8636
# Epoch : 58 of 100, Train Loss : 0.3344 , Train Accuracy : 0.8825, Test Accuracy : 0.8600
# Epoch : 59 of 100, Train Loss : 0.3240 , Train Accuracy : 0.8839, Test Accuracy : 0.8551
# Epoch : 60 of 100, Train Loss : 0.3174 , Train Accuracy : 0.8884, Test Accuracy : 0.8605
# Epoch : 61 of 100, Train Loss : 0.3044 , Train Accuracy : 0.8916, Test Accuracy : 0.8580
# Epoch : 62 of 100, Train Loss : 0.2958 , Train Accuracy : 0.8946, Test Accuracy : 0.8605
# Epoch : 63 of 100, Train Loss : 0.2865 , Train Accuracy : 0.8994, Test Accuracy : 0.8624
# Epoch : 64 of 100, Train Loss : 0.2834 , Train Accuracy : 0.9007, Test Accuracy : 0.8612
# Epoch : 65 of 100, Train Loss : 0.2731 , Train Accuracy : 0.9037, Test Accuracy : 0.8643
# Epoch : 66 of 100, Train Loss : 0.2646 , Train Accuracy : 0.9083, Test Accuracy : 0.8660
# Epoch : 67 of 100, Train Loss : 0.2607 , Train Accuracy : 0.9082, Test Accuracy : 0.8641
# Epoch : 68 of 100, Train Loss : 0.2534 , Train Accuracy : 0.9113, Test Accuracy : 0.8583
# Epoch : 69 of 100, Train Loss : 0.2422 , Train Accuracy : 0.9148, Test Accuracy : 0.8645
# Epoch : 70 of 100, Train Loss : 0.2392 , Train Accuracy : 0.9166, Test Accuracy : 0.8698
# Epoch : 71 of 100, Train Loss : 0.2366 , Train Accuracy : 0.9179, Test Accuracy : 0.8651
# Epoch : 72 of 100, Train Loss : 0.2279 , Train Accuracy : 0.9212, Test Accuracy : 0.8668
# Epoch : 73 of 100, Train Loss : 0.2282 , Train Accuracy : 0.9197, Test Accuracy : 0.8725
# Epoch : 74 of 100, Train Loss : 0.2189 , Train Accuracy : 0.9231, Test Accuracy : 0.8663
# Epoch : 75 of 100, Train Loss : 0.2126 , Train Accuracy : 0.9244, Test Accuracy : 0.8694
# Epoch : 76 of 100, Train Loss : 0.2085 , Train Accuracy : 0.9266, Test Accuracy : 0.8654
# Epoch : 77 of 100, Train Loss : 0.2038 , Train Accuracy : 0.9295, Test Accuracy : 0.8702
# Epoch : 78 of 100, Train Loss : 0.1975 , Train Accuracy : 0.9318, Test Accuracy : 0.8698
# Epoch : 79 of 100, Train Loss : 0.1932 , Train Accuracy : 0.9326, Test Accuracy : 0.8723
# Epoch : 80 of 100, Train Loss : 0.1915 , Train Accuracy : 0.9338, Test Accuracy : 0.8719
# Epoch : 81 of 100, Train Loss : 0.1889 , Train Accuracy : 0.9342, Test Accuracy : 0.8718
# Epoch : 82 of 100, Train Loss : 0.1848 , Train Accuracy : 0.9351, Test Accuracy : 0.8734
# Epoch : 83 of 100, Train Loss : 0.1820 , Train Accuracy : 0.9367, Test Accuracy : 0.8718
# Epoch : 84 of 100, Train Loss : 0.1754 , Train Accuracy : 0.9406, Test Accuracy : 0.8726
# Epoch : 85 of 100, Train Loss : 0.1734 , Train Accuracy : 0.9390, Test Accuracy : 0.8719
# Epoch : 86 of 100, Train Loss : 0.1719 , Train Accuracy : 0.9402, Test Accuracy : 0.8736
# Epoch : 87 of 100, Train Loss : 0.1714 , Train Accuracy : 0.9396, Test Accuracy : 0.8726
# Epoch : 88 of 100, Train Loss : 0.1664 , Train Accuracy : 0.9416, Test Accuracy : 0.8726
# Epoch : 89 of 100, Train Loss : 0.1683 , Train Accuracy : 0.9429, Test Accuracy : 0.8730
# Epoch : 90 of 100, Train Loss : 0.1607 , Train Accuracy : 0.9445, Test Accuracy : 0.8725
# Epoch : 91 of 100, Train Loss : 0.1631 , Train Accuracy : 0.9440, Test Accuracy : 0.8744
# Epoch : 92 of 100, Train Loss : 0.1642 , Train Accuracy : 0.9433, Test Accuracy : 0.8733
# Epoch : 93 of 100, Train Loss : 0.1621 , Train Accuracy : 0.9431, Test Accuracy : 0.8754
# Epoch : 94 of 100, Train Loss : 0.1616 , Train Accuracy : 0.9437, Test Accuracy : 0.8759
# Epoch : 95 of 100, Train Loss : 0.1576 , Train Accuracy : 0.9446, Test Accuracy : 0.8749
# Epoch : 96 of 100, Train Loss : 0.1564 , Train Accuracy : 0.9464, Test Accuracy : 0.8749
# Epoch : 97 of 100, Train Loss : 0.1590 , Train Accuracy : 0.9447, Test Accuracy : 0.8747
# Epoch : 98 of 100, Train Loss : 0.1575 , Train Accuracy : 0.9463, Test Accuracy : 0.8750
# Epoch : 99 of 100, Train Loss : 0.1603 , Train Accuracy : 0.9447, Test Accuracy : 0.8751
# Epoch : 100 of 100, Train Loss : 0.1559 , Train Accuracy : 0.9456, Test Accuracy : 0.8753

# %%
plt.plot(train_accuracies, label = "Train Accuracy")
plt.plot(test_accuracies, label = "Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Train and Test Accuracies, 12 MHA blocks, 12 Transformer layers")
plt.savefig("VisionTransformer-12Layers-12Blocks.png",  dpi=300)
plt.show()

# %%
torch.save(model, 'VisinTransformer_12Layers_Cifar10_AdamW.pth')
