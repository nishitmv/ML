# %%
from torch import optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np 
import random
import torchvision 
import torch.nn.functional as functional

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
# !nvidia-smi
# Out:
# Sun Dec 14 09:14:50 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.80                 Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 34%   28C    P8            N/A  /  115W |    5136MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1084    C+G   C:\Windows\System32\dwm.exe           N/A      |
# |    0   N/A  N/A            2680    C+G   ....0.3650.80\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            5212    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A            8540    C+G   ...r\Mystic Light\LEDKeeper2.exe      N/A      |
# |    0   N/A  N/A            9096    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            9612    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            9764    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           10012    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           10848    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12604    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           12832    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           14356    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           14588    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           14712    C+G   ...ce\root\Office16\POWERPNT.EXE      N/A      |
# |    0   N/A  N/A           15464    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           16032    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           17600    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           18056    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20244    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           20864    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           21056    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           21628    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           22700    C+G   ...ams\Perplexity\Perplexity.exe      N/A      |
# |    0   N/A  N/A           25192    C+G   ...abra\Direct6\jabra-direct.exe      N/A      |
# |    0   N/A  N/A           25940    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           26556    C+G   ...yApp\MicrosoftSecurityApp.exe      N/A      |
# |    0   N/A  N/A           26588    C+G   ...__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A           27328    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           28148    C+G   ...64__8wekyb3d8bbwe\Copilot.exe      N/A      |
# |    0   N/A  N/A           29604    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           30280    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           32304    C+G   ....0.3650.80\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           32360      C   ...sics\.venv\Scripts\python.exe      N/A      |
# |    0   N/A  N/A           33892    C+G   ...ata\Roaming\Zoom\bin\Zoom.exe      N/A      |
# |    0   N/A  N/A           34084    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           35088      C   ...sics\.venv\Scripts\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Setting uniform seed

# %%
torch.manual_seed(32)
torch.cuda.manual_seed(32)
random.seed(42)

# %%
# Set Hyper Parameters

# %%
BATCH_SIZE = 128
EPOCHS = 10
LEARNING_RATE = 3e-4
LION_LEARNING_RATE= 1e-4
PATCH_SIZE = 4
NUM_CLASSES=10 # for CIFAR
IMAGE_SIZE = 32
CHANNELS = 3
EMBEDDING_DIM = 384
NUM_HEADS = 8
DEPTH = 12 # Number of Transformer Encoder Blocks
MLP_DIM = 512
DROPOUT_RATE=0.1

# %%
#Patch Embedding , Create patches and return Tensor of Dimansion :  128 X 65 X 384 : 128 images 65 tokens(patches + CLS) per image, 
#384d per token (384d vector per patch)

class PatchEmbedding(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, embedding_dim):
        super().__init__()
        self.patch_size = patch_size
       # IMPORTANT : Use Convolution 2d as Projection Layer as its more efficient than a Linear Layer . The paper actually Mentions a Linear Layer . 
       # kernel and stride are assigned to patch size as we want patches and not overlaps  
        self.projection = nn.Conv2d(in_channels = in_channels, out_channels = embedding_dim, kernel_size = patch_size , stride=patch_size)
       # For square images number of patches is (image size/patch size) ^2         
        num_patches = (image_size//patch_size)**2
        #The CLS token (classification token) in Vision Transformers is a special learnable parameter that serves as a placeholder
        #for aggregating global information from all image patches for classification tasks
        self.pos_embed = nn.Parameter(torch.randn(1, num_patches + 1, embedding_dim))
      #  self.cls_token = nn.Parameter(torch.randn(1, 1, embedding_dim)) # Random to begin with

                                      
    def forward(self, tensor: torch.Tensor):
            # Tensor is 128 X 3 X 32 X 32 ( 3 , 32, 32 is the image 32X32 with 3 channels) 
            batch_size = tensor.size(0) # Get Batch Size 
            projected_tensor = self.projection(tensor)  # Each patch becomes 384d feature vector Tensor is now : 128*384*8*8
            flattened_tensor = projected_tensor.flatten(2) # flatten 128*384*8*8 to 128, 384, 64
            transposed_tensor = flattened_tensor.transpose(1,2) # swap to : 128 *64*384 converts tensor to format (batch_size, sequence_length, embedding_dim) by swapping dims: 
          #  cls_token = self.cls_token.expand(batch_size, -1, -1) # cls_token is replicated to all 128 images in the batch 
          #  tensor_with_cls_token = torch.cat((cls_token, transposed_tensor), dim=1)   # CLS Token in position 0 , Position 1 to 64 image patches
           # print(transposed_tensor.shape)
            #tensor_with_Pos_Embed = transposed_tensor + self.pos_embed 
         #   print(tensor_with_Pos_Embed.shape)
            return transposed_tensor # 128 X 65 X 384 : 128 images 65 tokens per image ( CLS token + 64 Patches), 384D representation of each token

# %%
class MLP(nn.Module):
    def __init__(self, in_features, hidden_features, dropout_rate):
        super().__init__()
        self.fc1 = nn.Linear(in_features=in_features, out_features=hidden_features)
        self.fc2 = nn.Linear(in_features=hidden_features, out_features=in_features)
        self.dropout = nn.Dropout(dropout_rate)
    def forward(self, tensor): # EXPAND ACTIVATE PROJECT BACK , Maintains original Dimensions 
        tensor = self.fc1(tensor)  # Tensor is  128 X 65 X 384 , output is 128 X 65 X 512
        tensor = self.dropout(functional.gelu(tensor)) # Input & output is 128 X 65 X 512 , Activation Function : Gaussian Error Linear Unit
        tensor = self.dropout(self.fc2(tensor)) # input is 128 X 65 X 512 and output is 128 X 65 X 384
        return tensor

# %%
class ConvTransformerEncoder(nn.Module): 
    def __init__(self, embedding_dim, num_heads, mlp_dim, dropout_rate):
        super().__init__()
        self.norm1 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        # Strides for Convolution as per CVT Paper
        self.q_stride = 1
        self.k_stride = 1
        self.v_stride = 1
        self.kernel_size = 3
        self.in_channels = self.out_channels = embedding_dim
        self.groups = embedding_dim

        # Convolutions for Q K and V . groups is the MOST important thing , as groups  = embedding dimension , 
        # convolution runs on each channel with a 3X3 Kernel, capturing information about neighbors . 
        # Thats why we dont need Positional Embedding , and this is called Local Inductive Bias . 
        
        self.conv_q = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.q_stride,
                                groups = self.groups
                                )

        self.conv_k = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.k_stride,
                                groups = self.groups
                                )

        self.conv_v = nn.Conv2d(in_channels=self.in_channels, 
                                out_channels=self.out_channels, 
                                kernel_size=self.kernel_size,
                                padding = 1,
                                stride = self.v_stride,
                                groups = self.groups
                                )
        
        # Each head will process embed_dim/num_heads dimensions so embed_dim%num_heads should be 0 . 
        #batch_first=True: Input shape is (batch, seq, features) → (128, 65, 384)
        # Each head processes: 384 / 12 = 32 dimensions for 12 heads
        # Internally reshaped to: (128, 65, 12, 32) (batch seq heads head_dim) ; Output Concatenated Back to 128 X 65 X 384
        # Pre Norm Architecture ( Norm before addign to Multi Head Attenstion as per VIT Paper)  stabilizes gradients during training, enables training of deeper networks
        #often converges faster than the original "post-norm" design from Attention paper
        self.multiHeadAttn = nn.MultiheadAttention(embed_dim=embedding_dim, num_heads=num_heads, dropout=dropout_rate, batch_first=True)
        # normalizing before each major operation prevents gradient Explosion and Vanishing Gradients during Back Prop
        self.norm2 = nn.LayerNorm(embedding_dim) # Mean 0 STD 1 
        #  position-wise feed-forward network MLP : Applier Non Linear Transformation on the token generated from MHA 
        # MLP applies the same transformation independently to each of the 65 tokens ( 64 Patches + CLS Token ) 
        self.mlp = MLP(embedding_dim, mlp_dim, dropout_rate)

    def forward(self, tensor : torch.Tensor ):
        # Input shape : [128, 65, 384]
      # Remove CLS Token from pensor and perform convolutions on patches only 
        #cls_token = tensor[:, 0:1, :]  # [128, 1, 384]  REMOVE THE CLASS TOKEN 
      #  patches = tensor[:, 1:, :]     # [128, 64, 384]
        patches = tensor
        batch_size, num_patches, embed_dim = patches.shape # 128, 64, 384
        #print("Input Tensor Shape ", tensor.shape)
        #print("batch Size ", batch_size)
        #print("num patches", num_patches)
        #print("Embedding Dim ", embed_dim)
        height = width = np.sqrt(num_patches).astype(np.int64) 
        # Normalize - Layer Norm
        patches = self.norm1(patches)
        #print("Normalized Tensor Shape ", patches.shape)
        patches_transposed = patches.transpose(1,2) #128 64 384 -> 128 384 64
        # Convert to Spacial Format for Convolution
        #print("Transposed Tensor Shape", patches_transposed.shape)
        patches_spacial = patches_transposed.reshape(batch_size, embed_dim, height, width) # [128, 384, 8, 8] 
        
        q = self.conv_q(patches_spacial) # [128, 384, 8, 8]
        k = self.conv_k(patches_spacial) # [128, 384, 8, 8]
        v = self.conv_v(patches_spacial) # [128, 384, 8, 8]
        # back to sequence format for attention - > Flatten and Transpose 
        q = q.flatten(2).transpose(1, 2) # 128, 64, 384
        k = k.flatten(2).transpose(1, 2) # 128, 64, 384
        v = v.flatten(2).transpose(1, 2) # 128, 64, 384 
        #q_with_cls = torch.cat([cls_token, q], dim=1) # [128, 65, 384]
        #k_with_cls = torch.cat([cls_token, k], dim=1) # [128, 65, 384]
        #v_with_cls = torch.cat([cls_token, v], dim=1) # [128, 65, 384]
        #print("q after adding cls token", q_with_cls.shape)
        # q k v for Mutlihead Self Attention come from convolutions unlike VIT
        attn_output, attn_weights = self.multiHeadAttn(query = q , key= k , value = v) 
        tensor = tensor + attn_output # Residual Conenction : Add Original Input to the output from Multi Head Attention 
        tensor = tensor + self.mlp(self.norm2(tensor)) 
        return tensor # Shape 128 X 65 X 384 maintained

# %%
class VisionTransformer(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, num_classes, embedding_dim, depth, num_heads, mlp_dims, dropout_rate):
        super().__init__()
        self.patch_embed = PatchEmbedding(image_size, patch_size, in_channels, embedding_dim)
        self.encoder = nn.Sequential(
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate),
            ConvTransformerEncoder(embedding_dim, num_heads, mlp_dims, dropout_rate)
            
        )
        self.norm = nn.LayerNorm(embedding_dim)
        # logits=W⋅x+b , Output is logits of num classes size vector
        self.classification_head = nn.Linear(in_features = embedding_dim, out_features= 100) # Linear Classification Head 

    def forward(self, tensor):
        tensor_with_Pos_Embed = self.patch_embed(tensor)
        encoder_output = self.encoder(tensor_with_Pos_Embed)
        normed_encoder_output = self.norm(encoder_output)
        # Global Average Pooling (GAP)
        G_A_P_OP = normed_encoder_output.mean(dim=1) # 
        return self.classification_head(G_A_P_OP) # Output Shape is 128 X 100  ( 100 Classes)

# %%
# Init the Vision transformer Model

model = VisionTransformer(IMAGE_SIZE, PATCH_SIZE,CHANNELS,NUM_CLASSES, EMBEDDING_DIM, DEPTH, NUM_HEADS, MLP_DIM, DROPOUT_RATE ).to(device)

# %%
model
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbedding(
#     (projection): Conv2d(3, 384, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (encoder): Sequential(
#     (0): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (7): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (8): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (9): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (10): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (11): ConvTransformerEncoder(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (conv_q): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_k): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (conv_v): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#       (multiHeadAttn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=384, out_features=384, bias=True)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (fc1): Linear(in_features=384, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classification_head): Linear(in_features=384, out_features=100, bias=True)
# )

# %%
# IMAGE TRANSFORM and dataset prep

# %%
cifar100_mean = [0.5071, 0.4865, 0.4409]
cifar100_std = [0.2673,0.2564,0.2762]

train_transformer = transforms.Compose([
transforms.RandomCrop(32, padding=4),    
transforms.RandomHorizontalFlip(),
transforms.RandAugment(num_ops=2, magnitude=9),
transforms.ToTensor(),
transforms.Normalize(cifar100_mean, cifar100_std),
    
])

train_dataset = datasets.CIFAR100(root="cifar100_data", train=True, download = True, transform = train_transformer)

# %%
train_dataset
# Out:
# Dataset CIFAR100
#     Number of datapoints: 50000
#     Root location: cifar100_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                RandAugment(num_ops=2, magnitude=9, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#                ToTensor()
#                Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2762])
#            )

# %%
# Load Testing Data 

test_transformer = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize(cifar100_mean, cifar100_std)
])

test_dataset = datasets.CIFAR100(root="cifar100_data", train=False, download = True, transform = test_transformer)

# %%
test_dataset
# Out:
# Dataset CIFAR100
#     Number of datapoints: 10000
#     Root location: cifar100_data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2762])
#            )

# %%
#DataLoaders

dataloader_train = DataLoader(train_dataset, batch_size=128, shuffle=True)
dataloader_test = DataLoader(test_dataset, batch_size=128, shuffle=False)

print(f"TRAIN DATALOADER : {len(dataloader_train)} batches")
print(f"TEST DATALOADER : {len(dataloader_test)} batches")
# Out:
# TRAIN DATALOADER : 391 batches
# TEST DATALOADER : 79 batches

# %%
# Training

def train(model, loader : DataLoader, optimizer, loss_function):
    model.train()
    correct, total_loss = 0, 0  
    for img_batch, labels in loader:
        img_batch = img_batch.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        output = model(img_batch)
        loss = loss_function(output, labels)
        loss.backward() # Back Prop 
        optimizer.step() # gradient Descent
        total_loss+= loss.item() * img_batch.size(0)
        correct+= (output.argmax(1)==labels).sum().item()
    return total_loss/len(loader.dataset) , correct/len(loader.dataset)

# %%
# Evaluation
def evaluate_model(model, loader : DataLoader):
    model.eval()
    correct = 0
    with torch.inference_mode():
        for img_batch, labels in loader:
            img_batch = img_batch.to(device)
            labels = labels.to(device)
            output = model(img_batch)
            predictions = output.argmax(dim=1)
            correct+= (predictions==labels).sum().item()
        return correct/len(loader.dataset)

# %%
#from tqdm.auto import tqdm

# %%
from lion_pytorch import Lion

train_accuracies, test_accuracies = [], []
EPOCHS=100
# Cross Entropy Loss and AdamW Optimizer 
loss_function = nn.CrossEntropyLoss()
#optimizer_lion = Lion(model.parameters(), lr=3e-5, weight_decay=0.1)


optimizer = optim.AdamW(params=model.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.999), weight_decay=0.01) 
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)
 
for epoch in range(EPOCHS):
    train_loss, train_acc = train(model, dataloader_train, optimizer, loss_function)
    test_acc = evaluate_model(model, dataloader_test)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch : {epoch+1} of {EPOCHS}, Train Loss : {train_loss:.4f} , Train Accuracy : {train_acc:.4f}, Test Accuracy : {test_acc:.4f}")
    scheduler.step()
# Out:
# Epoch : 1 of 100, Train Loss : 4.0650 , Train Accuracy : 0.0786, Test Accuracy : 0.1630
# Epoch : 2 of 100, Train Loss : 3.4513 , Train Accuracy : 0.1726, Test Accuracy : 0.2609
# Epoch : 3 of 100, Train Loss : 3.0585 , Train Accuracy : 0.2455, Test Accuracy : 0.3146
# Epoch : 4 of 100, Train Loss : 2.7596 , Train Accuracy : 0.3022, Test Accuracy : 0.3802
# Epoch : 5 of 100, Train Loss : 2.5352 , Train Accuracy : 0.3486, Test Accuracy : 0.4161
# Epoch : 6 of 100, Train Loss : 2.3420 , Train Accuracy : 0.3934, Test Accuracy : 0.4553
# Epoch : 7 of 100, Train Loss : 2.1869 , Train Accuracy : 0.4264, Test Accuracy : 0.4779
# Epoch : 8 of 100, Train Loss : 2.0594 , Train Accuracy : 0.4531, Test Accuracy : 0.4898
# Epoch : 9 of 100, Train Loss : 1.9328 , Train Accuracy : 0.4796, Test Accuracy : 0.5313
# Epoch : 10 of 100, Train Loss : 1.8286 , Train Accuracy : 0.5047, Test Accuracy : 0.5440
# Epoch : 11 of 100, Train Loss : 1.7352 , Train Accuracy : 0.5274, Test Accuracy : 0.5526
# Epoch : 12 of 100, Train Loss : 1.6523 , Train Accuracy : 0.5457, Test Accuracy : 0.5633
# Epoch : 13 of 100, Train Loss : 1.5723 , Train Accuracy : 0.5664, Test Accuracy : 0.5734
# Epoch : 14 of 100, Train Loss : 1.5008 , Train Accuracy : 0.5822, Test Accuracy : 0.5827
# Epoch : 15 of 100, Train Loss : 1.4259 , Train Accuracy : 0.6008, Test Accuracy : 0.5969
# Epoch : 16 of 100, Train Loss : 1.3648 , Train Accuracy : 0.6164, Test Accuracy : 0.5995
# Epoch : 17 of 100, Train Loss : 1.2925 , Train Accuracy : 0.6333, Test Accuracy : 0.5971
# Epoch : 18 of 100, Train Loss : 1.2291 , Train Accuracy : 0.6496, Test Accuracy : 0.6076
# Epoch : 19 of 100, Train Loss : 1.1844 , Train Accuracy : 0.6596, Test Accuracy : 0.6046
# Epoch : 20 of 100, Train Loss : 1.1294 , Train Accuracy : 0.6768, Test Accuracy : 0.6132
# Epoch : 21 of 100, Train Loss : 1.0657 , Train Accuracy : 0.6911, Test Accuracy : 0.6119
# Epoch : 22 of 100, Train Loss : 1.0291 , Train Accuracy : 0.6999, Test Accuracy : 0.6203
# Epoch : 23 of 100, Train Loss : 0.9707 , Train Accuracy : 0.7175, Test Accuracy : 0.6193
# Epoch : 24 of 100, Train Loss : 0.9179 , Train Accuracy : 0.7306, Test Accuracy : 0.6238
# Epoch : 25 of 100, Train Loss : 0.8874 , Train Accuracy : 0.7380, Test Accuracy : 0.6253
# Epoch : 26 of 100, Train Loss : 0.8343 , Train Accuracy : 0.7548, Test Accuracy : 0.6312
# Epoch : 27 of 100, Train Loss : 0.8012 , Train Accuracy : 0.7631, Test Accuracy : 0.6250
# Epoch : 28 of 100, Train Loss : 0.7634 , Train Accuracy : 0.7746, Test Accuracy : 0.6340
# Epoch : 29 of 100, Train Loss : 0.7267 , Train Accuracy : 0.7851, Test Accuracy : 0.6282
# Epoch : 30 of 100, Train Loss : 0.6910 , Train Accuracy : 0.7959, Test Accuracy : 0.6330
# Epoch : 31 of 100, Train Loss : 0.6577 , Train Accuracy : 0.8031, Test Accuracy : 0.6303
# Epoch : 32 of 100, Train Loss : 0.6307 , Train Accuracy : 0.8103, Test Accuracy : 0.6337
# Epoch : 33 of 100, Train Loss : 0.5957 , Train Accuracy : 0.8229, Test Accuracy : 0.6310
# Epoch : 34 of 100, Train Loss : 0.5676 , Train Accuracy : 0.8315, Test Accuracy : 0.6368
# Epoch : 35 of 100, Train Loss : 0.5423 , Train Accuracy : 0.8375, Test Accuracy : 0.6331
# Epoch : 36 of 100, Train Loss : 0.5264 , Train Accuracy : 0.8418, Test Accuracy : 0.6350
# Epoch : 37 of 100, Train Loss : 0.4982 , Train Accuracy : 0.8522, Test Accuracy : 0.6414
# Epoch : 38 of 100, Train Loss : 0.4785 , Train Accuracy : 0.8578, Test Accuracy : 0.6355
# Epoch : 39 of 100, Train Loss : 0.4532 , Train Accuracy : 0.8664, Test Accuracy : 0.6375
# Epoch : 40 of 100, Train Loss : 0.4373 , Train Accuracy : 0.8693, Test Accuracy : 0.6381
# Epoch : 41 of 100, Train Loss : 0.4174 , Train Accuracy : 0.8769, Test Accuracy : 0.6286
# Epoch : 42 of 100, Train Loss : 0.4063 , Train Accuracy : 0.8806, Test Accuracy : 0.6386
# Epoch : 43 of 100, Train Loss : 0.3915 , Train Accuracy : 0.8826, Test Accuracy : 0.6372
# Epoch : 44 of 100, Train Loss : 0.3702 , Train Accuracy : 0.8898, Test Accuracy : 0.6409
# Epoch : 45 of 100, Train Loss : 0.3489 , Train Accuracy : 0.8954, Test Accuracy : 0.6357
# Epoch : 46 of 100, Train Loss : 0.3435 , Train Accuracy : 0.8977, Test Accuracy : 0.6383
# Epoch : 47 of 100, Train Loss : 0.3289 , Train Accuracy : 0.9028, Test Accuracy : 0.6356
# Epoch : 48 of 100, Train Loss : 0.3150 , Train Accuracy : 0.9070, Test Accuracy : 0.6371
# Epoch : 49 of 100, Train Loss : 0.3099 , Train Accuracy : 0.9089, Test Accuracy : 0.6445
# Epoch : 50 of 100, Train Loss : 0.2950 , Train Accuracy : 0.9144, Test Accuracy : 0.6408
# Epoch : 51 of 100, Train Loss : 0.2820 , Train Accuracy : 0.9165, Test Accuracy : 0.6432
# Epoch : 52 of 100, Train Loss : 0.2829 , Train Accuracy : 0.9167, Test Accuracy : 0.6404
# Epoch : 53 of 100, Train Loss : 0.2649 , Train Accuracy : 0.9219, Test Accuracy : 0.6367
# Epoch : 54 of 100, Train Loss : 0.2576 , Train Accuracy : 0.9241, Test Accuracy : 0.6468
# Epoch : 55 of 100, Train Loss : 0.2447 , Train Accuracy : 0.9286, Test Accuracy : 0.6426
# Epoch : 56 of 100, Train Loss : 0.2367 , Train Accuracy : 0.9313, Test Accuracy : 0.6452
# Epoch : 57 of 100, Train Loss : 0.2251 , Train Accuracy : 0.9345, Test Accuracy : 0.6472
# Epoch : 58 of 100, Train Loss : 0.2154 , Train Accuracy : 0.9365, Test Accuracy : 0.6519
# Epoch : 59 of 100, Train Loss : 0.2134 , Train Accuracy : 0.9379, Test Accuracy : 0.6449
# Epoch : 60 of 100, Train Loss : 0.2005 , Train Accuracy : 0.9424, Test Accuracy : 0.6522
# Epoch : 61 of 100, Train Loss : 0.1946 , Train Accuracy : 0.9436, Test Accuracy : 0.6450
# Epoch : 62 of 100, Train Loss : 0.1877 , Train Accuracy : 0.9458, Test Accuracy : 0.6484
# Epoch : 63 of 100, Train Loss : 0.1831 , Train Accuracy : 0.9475, Test Accuracy : 0.6471
# Epoch : 64 of 100, Train Loss : 0.1749 , Train Accuracy : 0.9492, Test Accuracy : 0.6510
# Epoch : 65 of 100, Train Loss : 0.1702 , Train Accuracy : 0.9504, Test Accuracy : 0.6507
# Epoch : 66 of 100, Train Loss : 0.1650 , Train Accuracy : 0.9521, Test Accuracy : 0.6513
# Epoch : 67 of 100, Train Loss : 0.1570 , Train Accuracy : 0.9545, Test Accuracy : 0.6504
# Epoch : 68 of 100, Train Loss : 0.1525 , Train Accuracy : 0.9565, Test Accuracy : 0.6582
# Epoch : 69 of 100, Train Loss : 0.1501 , Train Accuracy : 0.9571, Test Accuracy : 0.6562
# Epoch : 70 of 100, Train Loss : 0.1432 , Train Accuracy : 0.9589, Test Accuracy : 0.6537
# Epoch : 71 of 100, Train Loss : 0.1432 , Train Accuracy : 0.9582, Test Accuracy : 0.6516
# Epoch : 72 of 100, Train Loss : 0.1338 , Train Accuracy : 0.9610, Test Accuracy : 0.6582
# Epoch : 73 of 100, Train Loss : 0.1275 , Train Accuracy : 0.9635, Test Accuracy : 0.6569
# Epoch : 74 of 100, Train Loss : 0.1257 , Train Accuracy : 0.9643, Test Accuracy : 0.6518
# Epoch : 75 of 100, Train Loss : 0.1216 , Train Accuracy : 0.9653, Test Accuracy : 0.6599
# Epoch : 76 of 100, Train Loss : 0.1179 , Train Accuracy : 0.9660, Test Accuracy : 0.6562
# Epoch : 77 of 100, Train Loss : 0.1163 , Train Accuracy : 0.9677, Test Accuracy : 0.6553
# Epoch : 78 of 100, Train Loss : 0.1110 , Train Accuracy : 0.9680, Test Accuracy : 0.6573
# Epoch : 79 of 100, Train Loss : 0.1115 , Train Accuracy : 0.9675, Test Accuracy : 0.6577
# Epoch : 80 of 100, Train Loss : 0.1048 , Train Accuracy : 0.9704, Test Accuracy : 0.6589
# Epoch : 81 of 100, Train Loss : 0.1036 , Train Accuracy : 0.9706, Test Accuracy : 0.6545
# Epoch : 82 of 100, Train Loss : 0.1030 , Train Accuracy : 0.9716, Test Accuracy : 0.6598
# Epoch : 83 of 100, Train Loss : 0.0962 , Train Accuracy : 0.9721, Test Accuracy : 0.6579
# Epoch : 84 of 100, Train Loss : 0.0938 , Train Accuracy : 0.9741, Test Accuracy : 0.6580
# Epoch : 85 of 100, Train Loss : 0.0945 , Train Accuracy : 0.9726, Test Accuracy : 0.6595
# Epoch : 86 of 100, Train Loss : 0.0909 , Train Accuracy : 0.9743, Test Accuracy : 0.6583
# Epoch : 87 of 100, Train Loss : 0.0956 , Train Accuracy : 0.9725, Test Accuracy : 0.6585
# Epoch : 88 of 100, Train Loss : 0.0880 , Train Accuracy : 0.9750, Test Accuracy : 0.6584
# Epoch : 89 of 100, Train Loss : 0.0867 , Train Accuracy : 0.9753, Test Accuracy : 0.6607
# Epoch : 90 of 100, Train Loss : 0.0844 , Train Accuracy : 0.9762, Test Accuracy : 0.6616
# Epoch : 91 of 100, Train Loss : 0.0875 , Train Accuracy : 0.9755, Test Accuracy : 0.6609
# Epoch : 92 of 100, Train Loss : 0.0836 , Train Accuracy : 0.9765, Test Accuracy : 0.6612
# Epoch : 93 of 100, Train Loss : 0.0867 , Train Accuracy : 0.9758, Test Accuracy : 0.6603
# Epoch : 94 of 100, Train Loss : 0.0864 , Train Accuracy : 0.9753, Test Accuracy : 0.6608
# Epoch : 95 of 100, Train Loss : 0.0861 , Train Accuracy : 0.9763, Test Accuracy : 0.6617
# Epoch : 96 of 100, Train Loss : 0.0848 , Train Accuracy : 0.9767, Test Accuracy : 0.6609
# Epoch : 97 of 100, Train Loss : 0.0829 , Train Accuracy : 0.9767, Test Accuracy : 0.6615
# Epoch : 98 of 100, Train Loss : 0.0832 , Train Accuracy : 0.9769, Test Accuracy : 0.6611
# Epoch : 99 of 100, Train Loss : 0.0823 , Train Accuracy : 0.9767, Test Accuracy : 0.6611
# Epoch : 100 of 100, Train Loss : 0.0841 , Train Accuracy : 0.9768, Test Accuracy : 0.6611

# %%
plt.plot(train_accuracies, label = "Train Accuracy")
plt.plot(test_accuracies, label = "Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Train and Test Accuracies, Conv Vision Transformer  ")
plt.savefig("ConvVisionTransformer-NoCLSToken-GAP-CIFAR100",  dpi=300)
plt.show()

# %%
torch.save(model, 'ConvVisionTransformer-NoCLSToken-GAP-CIFAR100.pth')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score
from torchmetrics.classification import AUROC

model = torch.load('ConvVisionTransformer-NoCLSToken-GAP-CIFAR100.pth', weights_only=False)

def test_model(model, loader : DataLoader):
    model.eval()
    correct = 0
    all_labels = []
    all_predictions = []
    with torch.inference_mode():
        for img_batch, labels in loader:
            img_batch = img_batch.to(device)
            labels = labels.to(device)
            output = model(img_batch)
            predictions = output.argmax(dim=1)
            correct+= (predictions==labels).sum().item()
            all_labels.extend(labels.to("cpu").numpy())
            all_predictions.extend(predictions.to("cpu").numpy())
        return correct/len(loader.dataset), all_labels, all_predictions   

test_accuracy, all_labels, all_predictions = test_model(model, dataloader_test)
        
cm = confusion_matrix(all_labels, all_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig("ConvVisionTransformer-NoCLSToken-GAP-CIFAR100ConfusionMatrix.png",  dpi=300)
plt.show()

precision = precision_score(all_labels, all_predictions, average='weighted')
recall = recall_score(all_labels, all_predictions, average='weighted')
f1 = f1_score(all_labels, all_predictions, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# Precision: 0.66
# Recall:    0.66
# F1 Score:  0.66

# %%
grid_size = 5
fig, axes = plt.subplots(grid_size, grid_size, figsize = (9, 9))
classes = test_dataset.classes
model = torch.load('ConvVisionTransformer-NoCLSToken-GAP-CIFAR100.pth', weights_only=False)

model.eval()

for i in range(grid_size):
    for j in range(grid_size):
        index = random.randint(0, len(test_dataset) -1)
        img , correct_label = test_dataset[index]
        input_tensor = img.unsqueeze(dim=0).to(device)
        with torch.inference_mode():
            output = model(input_tensor)
            _, predicted = torch.max(output.data,1)
        img = img / 2 + 0.5 # denormalizing images to plot 
        nump_img = img.to("cpu")
        axes[i, j].imshow(np.transpose(nump_img, (1,2,0)))
        correct_match = classes[correct_label] == classes[predicted.item()]
        axes[i, j].set_title(f"Actual Label :  {classes[correct_label]} \n Predicted Label :  {classes[predicted.item()]},]" , fontsize = 10)
        axes[i, j].axis("off")
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.448713..1.4146622].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.43341827..1.3254757].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41812354..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.42577088..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.25555867..1.3926556].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.22693938..1.5050297].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.43388855..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.35694462..1.4624348].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.2578361..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41188204..1.2899585].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.24223411..1.4095967].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.28047097..0.9818666].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4410656..1.4219978].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.35319787..1.3062537].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.26517165..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.36053342..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41921753..1.3866546].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.448713..1.3926556].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41812354..1.4837325].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41921753..1.4172441].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.448713..1.4219978].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.448713..1.512129].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.44855958..1.4269392].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.030435026..1.1266443].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.448713..1.3630469].
